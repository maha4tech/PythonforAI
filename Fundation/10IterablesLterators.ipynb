# %% [markdown]
# ## List iterables vs Iterators

# %%
lst=[1,2,3,4,5,6,7,8]

# %%
# List is iterable via  memory 

for i in lst:
     print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
lst1= iter(lst)

# %%
next(lst1)
# Out:
# 1

# %%
for i in lst1:
     print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
